# %% [markdown]
# <a href="https://colab.research.google.com/github/korbendallas78/szakdoga/blob/main/szd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_p = pd.read_csv('E10_P011_PT01_DACA_PV.csv')
df_lm = pd.read_csv('E10_T01_LT01_DACA_PV_2023.csv')
df_lh = pd.read_csv('E10_T02_LT01_DACA_PV_2023.csv')
df_tm = pd.read_csv('E10_T01_TT02_DACA_PV_2023.csv')
df_th = pd.read_csv('E10_T02_TT02_DACA_PV_2023.csv')
df_a1 = pd.read_csv('E10_K1_AT01_PV_2023.csv')
df_r1 = pd.read_csv('E10_K1_RT01_PV_2023.csv')
df_t1 = pd.read_csv('E10_K1_TT05_PV_2023.csv')
df_t2 = pd.read_csv('E10_K2_TT05_PV_2023.csv')
df_t3 = pd.read_csv('E10_K3_TT05_PV_2023.csv')
df_t4 = pd.read_csv('E10_K4_TT05_PV_2023.csv')
df_p1 = pd.read_csv('E10_P011_PT01_DACA_PV_2023.csv')
df_p2 = pd.read_csv('E10_P012_PT01_DACA_PV_2023.csv')
df_p3 = pd.read_csv('E10_P013_PT01_DACA_PV_2023.csv')
df_p4 = pd.read_csv('E10_P014_PT01_DACA_PV_2023.csv')
df_f1 = pd.read_csv('E10_QT021_02_DACA_PV_2023.csv')
df_f2 = pd.read_csv('E10_QT022_02_DACA_PV_2023.csv')
df_f3 = pd.read_csv('E10_QT024_02_DACA_PV_2023.csv')
df_f4 = pd.read_csv('E10_QT026_02_DACA_PV_2023.csv')
df_f5 = pd.read_csv('E10_QT027_02_DACA_PV_2023.csv')

# %%
df_list1=[df_p,df_lm,df_lh,df_tm,df_th,df_a1,df_r1,df_t1,df_t2,df_t3,df_t4,df_p1,df_p2,df_p3,df_p4,df_f1,df_f2,df_f3,df_f4,df_f5]

# %%
df_list1[0]
# Out:
#         1/1/2023 12:00:00 AM   0.482233047485352    100
# 0       1/1/2023 12:01:00 AM            0.482144  100.0
# 1       1/1/2023 12:02:00 AM            0.482144  100.0
# 2       1/1/2023 12:03:00 AM            0.482322  100.0
# 3       1/1/2023 12:04:00 AM            0.482055  100.0
# 4       1/1/2023 12:05:00 AM            0.482233  100.0
# ...                      ...                 ...    ...
# 44634  1/31/2023 11:55:00 PM            1.022605  100.0
# 44635  1/31/2023 11:56:00 PM            1.022160  100.0
# 44636  1/31/2023 11:57:00 PM            1.021715  100.0
# 44637  1/31/2023 11:58:00 PM            1.022160  100.0
# 44638  1/31/2023 11:59:00 PM            1.000000    NaN
#
# [44639 rows x 3 columns]

# %%
for x in df_list1:
  x=x.drop(x.index[-1], inplace=True)

# %%
for x in df_list1:
  x[x.columns[0]] = pd.to_datetime(x[x.columns[0]], format='%m/%d/%Y %I:%M:%S %p')

# %%
df_p.columns =['Timestamp', 'Nyomas', 'Confidence']
df_lm.columns =['Timestamp', 'Szint_meleg', 'Confidence']
df_lh.columns =['Timestamp', 'Szint_hideg', 'Confidence']
df_tm.columns =['Timestamp', 'Homerseklet_meleg', 'Confidence']
df_th.columns =['Timestamp', 'Homerseklet_hideg', 'Confidence']
df_a1.columns =['Timestamp', 'Aram_k1', 'Confidence']
df_r1.columns =['Timestamp', 'Fordulat_k1', 'Confidence']
df_t1.columns =['Timestamp', 'Homerseklet_k1', 'Confidence']
df_t2.columns =['Timestamp', 'Homerseklet_k2', 'Confidence']
df_t3.columns =['Timestamp', 'Homerseklet_k3', 'Confidence']
df_t4.columns =['Timestamp', 'Homerseklet_k4', 'Confidence']
df_p1.columns =['Timestamp', 'Nyomas_k1', 'Confidence']
df_p2.columns =['Timestamp', 'Nyomas_k2', 'Confidence']
df_p3.columns =['Timestamp', 'Nyomas_k3', 'Confidence']
df_p4.columns =['Timestamp', 'Nyomas_k4', 'Confidence']
df_f1.columns =['Timestamp', 'Aramlas1', 'Confidence']
df_f2.columns =['Timestamp', 'Aramlas2', 'Confidence']
df_f3.columns =['Timestamp', 'Aramlas3', 'Confidence']
df_f4.columns =['Timestamp', 'Aramlas4', 'Confidence']
df_f5.columns =['Timestamp', 'Aramlas5', 'Confidence']

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44638 entries, 0 to 44637
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Timestamp   44638 non-null  datetime64[ns]
#  1   Nyomas      44638 non-null  float64
#  2   Confidence  44638 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.0 MB

# %%
for x in df_list1:
  x=x.drop(columns=['Confidence'], inplace = True)

# %%
df_list1[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44638 entries, 0 to 44637
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  44638 non-null  datetime64[ns]
#  1   Nyomas     44638 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 697.6 KB

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44638 entries, 0 to 44637
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  44638 non-null  datetime64[ns]
#  1   Nyomas     44638 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 697.6 KB

# %%
from functools import reduce

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=[df_list1[0].columns[0]],
                                            how='outer'), df_list1)

# %%
df_merged
# Out:
#                 Timestamp    Nyomas  Szint_meleg  Szint_hideg  \
# 0     2023-01-01 00:01:00  0.482144    50.242931    51.096893
# 1     2023-01-01 00:02:00  0.482144    50.241070    51.096893
# 2     2023-01-01 00:03:00  0.482322    50.242931    51.096893
# 3     2023-01-01 00:04:00  0.482055    50.242931    51.095005
# 4     2023-01-01 00:05:00  0.482233    50.237354    51.095005
# ...                   ...       ...          ...          ...
# 44633 2023-01-31 23:54:00  1.022783          NaN          NaN
# 44634 2023-01-31 23:55:00  1.022605          NaN          NaN
# 44635 2023-01-31 23:56:00  1.022160          NaN          NaN
# 44636 2023-01-31 23:57:00  1.021715          NaN          NaN
# 44637 2023-01-31 23:58:00  1.022160          NaN          NaN
#
#        Homerseklet_meleg  Homerseklet_hideg       Aram_k1  Fordulat_k1  \
# 0              -6.138716          -6.426277  4.139212e-09          0.0
# 1              -6.124478          -6.422711  4.139212e-09          0.0
# ...

# %%
# Create List of columns
toltes_list= ['Nyomas_k1', 'Nyomas_k2', 'Nyomas_k3', 'Nyomas_k4']

# Get sum of specific columns for each row
df_merged['Toltes'] = df_merged[toltes_list].sum(axis=1)
df_merged
# Out:
#                 Timestamp    Nyomas  Szint_meleg  Szint_hideg  \
# 0     2023-01-01 00:01:00  0.482144    50.242931    51.096893
# 1     2023-01-01 00:02:00  0.482144    50.241070    51.096893
# 2     2023-01-01 00:03:00  0.482322    50.242931    51.096893
# 3     2023-01-01 00:04:00  0.482055    50.242931    51.095005
# 4     2023-01-01 00:05:00  0.482233    50.237354    51.095005
# ...                   ...       ...          ...          ...
# 44633 2023-01-31 23:54:00  1.022783          NaN          NaN
# 44634 2023-01-31 23:55:00  1.022605          NaN          NaN
# 44635 2023-01-31 23:56:00  1.022160          NaN          NaN
# 44636 2023-01-31 23:57:00  1.021715          NaN          NaN
# 44637 2023-01-31 23:58:00  1.022160          NaN          NaN
#
#        Homerseklet_meleg  Homerseklet_hideg       Aram_k1  Fordulat_k1  \
# 0              -6.138716          -6.426277  4.139212e-09          0.0
# 1              -6.124478          -6.422711  4.139212e-09          0.0
# ...

# %%
# Create List of columns
aramlas_list= ['Aramlas1', 'Aramlas2', 'Aramlas3', 'Aramlas4','Aramlas5']

# Get sum of specific columns for each row
df_merged['Aramlas'] = df_merged[aramlas_list].sum(axis=1)
df_merged
# Out:
#                 Timestamp    Nyomas  Szint_meleg  Szint_hideg  \
# 0     2023-01-01 00:01:00  0.482144    50.242931    51.096893
# 1     2023-01-01 00:02:00  0.482144    50.241070    51.096893
# 2     2023-01-01 00:03:00  0.482322    50.242931    51.096893
# 3     2023-01-01 00:04:00  0.482055    50.242931    51.095005
# 4     2023-01-01 00:05:00  0.482233    50.237354    51.095005
# ...                   ...       ...          ...          ...
# 44633 2023-01-31 23:54:00  1.022783          NaN          NaN
# 44634 2023-01-31 23:55:00  1.022605          NaN          NaN
# 44635 2023-01-31 23:56:00  1.022160          NaN          NaN
# 44636 2023-01-31 23:57:00  1.021715          NaN          NaN
# 44637 2023-01-31 23:58:00  1.022160          NaN          NaN
#
#        Homerseklet_meleg  Homerseklet_hideg       Aram_k1  Fordulat_k1  \
# 0              -6.138716          -6.426277  4.139212e-09          0.0
# 1              -6.124478          -6.422711  4.139212e-09          0.0
# ...

# %%
df_uj=df_merged[['Timestamp', 'Homerseklet_hideg', 'Homerseklet_k1', 'Homerseklet_k2', 'Homerseklet_k3', 'Homerseklet_k4']]
df_uj
# Out:
#                 Timestamp  Homerseklet_hideg  Homerseklet_k1  Homerseklet_k2  \
# 0     2023-01-01 00:01:00          -6.426277            19.0       19.699999
# 1     2023-01-01 00:02:00          -6.422711            19.0       19.699999
# 2     2023-01-01 00:03:00          -6.422711            19.0       19.699999
# 3     2023-01-01 00:04:00          -6.424493            19.0       19.699999
# 4     2023-01-01 00:05:00          -6.428052            19.0       19.699999
# ...                   ...                ...             ...             ...
# 44633 2023-01-31 23:54:00         -11.853010             NaN       27.199999
# 44634 2023-01-31 23:55:00         -11.851230             NaN       27.199999
# 44635 2023-01-31 23:56:00         -11.865468             NaN       27.099998
# 44636 2023-01-31 23:57:00         -11.849451             NaN       27.199999
# 44637 2023-01-31 23:58:00                NaN             NaN       27.099998
#
#        Homerseklet_k3  Homerseklet_k4
# ...

# %%
plt.scatter(df_merged.iloc[:,0],df_merged.iloc[:,2])
plt.scatter(df_merged.iloc[:,0],df_merged.iloc[:,3])
plt.show()

# %%
df_szint=df_merged[['Timestamp', 'Szint_meleg', 'Szint_hideg','Toltes','Aramlas']]

# %%
df_szint.corr()
import seaborn as sns
sns.heatmap(df_szint.corr())
# Out:
# <ipython-input-20-b60b1ed875d9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_szint.corr()
# <ipython-input-20-b60b1ed875d9>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_szint.corr())
# <Axes: >

# %%
plt.scatter(df_szint.iloc[:,3],df_szint.iloc[:,4])

plt.show()

# %%
df_szint
# Out:
#                 Timestamp  Szint_meleg  Szint_hideg    Toltes    Aramlas
# 0     2023-01-01 00:01:00    50.242931    51.096893  0.664870   0.000000
# 1     2023-01-01 00:02:00    50.241070    51.096893  0.664959   0.000000
# 2     2023-01-01 00:03:00    50.242931    51.096893  0.664870   0.000000
# 3     2023-01-01 00:04:00    50.242931    51.095005  0.664870   0.001786
# 4     2023-01-01 00:05:00    50.237354    51.095005  0.664959   0.001786
# ...                   ...          ...          ...       ...        ...
# 44633 2023-01-31 23:54:00          NaN          NaN  1.966323  12.722006
# 44634 2023-01-31 23:55:00          NaN          NaN  1.964898   0.000000
# 44635 2023-01-31 23:56:00          NaN          NaN  1.965165   0.000000
# 44636 2023-01-31 23:57:00          NaN          NaN  1.965165   0.000000
# 44637 2023-01-31 23:58:00          NaN          NaN  1.965432   0.000000
#
# [44638 rows x 5 columns]

# %%
df_szint.fillna(df_szint.mean(),inplace = True)
# Out:
# <ipython-input-22-535cf116b56c>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df_szint.fillna(df_szint.mean(),inplace = True)
# <ipython-input-22-535cf116b56c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_szint.fillna(df_szint.mean(),inplace = True)

# %%
df_szint
# Out:
#                 Timestamp  Szint_meleg  Szint_hideg    Toltes    Aramlas
# 0     2023-01-01 00:01:00    50.242931    51.096893  0.664870   0.000000
# 1     2023-01-01 00:02:00    50.241070    51.096893  0.664959   0.000000
# 2     2023-01-01 00:03:00    50.242931    51.096893  0.664870   0.000000
# 3     2023-01-01 00:04:00    50.242931    51.095005  0.664870   0.001786
# 4     2023-01-01 00:05:00    50.237354    51.095005  0.664959   0.001786
# ...                   ...          ...          ...       ...        ...
# 44633 2023-01-31 23:54:00    53.593798    47.249141  1.966323  12.722006
# 44634 2023-01-31 23:55:00    53.593798    47.249141  1.964898   0.000000
# 44635 2023-01-31 23:56:00    53.593798    47.249141  1.965165   0.000000
# 44636 2023-01-31 23:57:00    53.593798    47.249141  1.965165   0.000000
# 44637 2023-01-31 23:58:00    53.593798    47.249141  1.965432   0.000000
#
# [44638 rows x 5 columns]

# %%
y = df_szint.iloc[:,[2]].values
X = df_szint.iloc[:,[3,4]].values

# %%
y
# Out:
# array([[51.09689331],
#        [51.09689331],
#        [51.09689331],
#        ...,
#        [47.24914053],
#        [47.24914053],
#        [47.24914053]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (35710, 2)

# %%
y_train.shape
# Out:
# (35710, 1)

# %%
pip install lazypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle

#Selectig initial 10 regressor
lazypredict.Supervised.REGRESSORS = lazypredict.Supervised.REGRESSORS[:10]
lazypredict.Supervised.REGRESSORS
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
#                        Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                  0.93       0.93  1.31       14.25
# BaggingRegressor                     0.93       0.93  1.33        2.81
# DecisionTreeRegressor                0.89       0.89  1.67        0.35
# ExtraTreeRegressor                   0.87       0.87  1.77        0.19
# AdaBoostRegressor                    0.56       0.56  3.30        1.80
# ElasticNetCV                         0.32       0.32  4.11        0.74
# BayesianRidge                        0.32       0.32  4.11        0.09
# ElasticNet                           0.23       0.23  4.37        0.05
# GammaRegressor                       0.21       0.21  4.42        0.20
# DummyRegressor                      -0.00      -0.00  4.98        0.02

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
reg = ExtraTreesRegressor(n_estimators=100, random_state=0).fit(X_train, y_train)
reg.score(X_test, y_test)
# Out:
# 0.9313136210643245

# %%
y_train_pred1 =reg.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("MAE =",mean_absolute_error(y_train,y_train_pred1))
print("MSE =",mean_squared_error(y_train,y_train_pred1))
print("RMSE =",np.sqrt(mean_squared_error(y_train,y_train_pred1)))
print("R2 =",r2_score(y_train,y_train_pred1))
# Out:
# MAE = 0.0008986800266752365
# MSE = 0.0008384230379568834
# RMSE = 0.02895553553220668
# R2 = 0.9999666076144348

# %%
crossval_r2 = pd.DataFrame(index=range(2,4),columns = ["training","validation"])

# %%
from sklearn.model_selection import KFold

# %%
d = 5
kf = KFold(n_splits=10)
for d in range(2,25):
  r2_train_list = []
  r2_valid_list= []
  for train, valid in kf.split(X_train):
    regTree = ExtraTreesRegressor(max_depth=d)
    regTree.fit(X_train[train,:], y_train[train])
    R2_train = r2_score(y_train[train],regTree.predict(X_train[train,:]))
    R2_valid = r2_score(y_train[valid],regTree.predict(X_train[valid,:]))
    r2_train_list.append(R2_train)
    r2_valid_list.append(R2_valid)
  crossval_r2.loc[d,"training"] = np.mean(r2_train_list)
  crossval_r2.loc[d,"validation"] = np.mean(r2_valid_list)

# %%
plt.scatter(crossval_r2.index,crossval_r2["training"],label="training")
plt.scatter(crossval_r2.index,crossval_r2["validation"],label="validation")
plt.xlabel("Komplexitas/Melyseg")
plt.ylabel("R2")
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

sc_y = StandardScaler()
y_train_sc = sc_y.fit_transform(y_train.reshape(len(y_train), 1))
y_test_sc = sc_y.transform(y_test.reshape(len(y_test), 1))

# %%
import tensorflow as tf

# %%
ann = tf.keras.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=4, activation='sigmoid',name='Rejtett1'))

# %%
ann.add(tf.keras.layers.Dense(units=10, activation='relu',name='Rejtett2'))

# %%
ann.add(tf.keras.layers.Dense(units=1,name='Kimenet'))

# %%
ann.compile(optimizer='adam',
              loss='mean_squared_error')

# %%
res = ann.fit(X_train, y_train,validation_data=(X_test, y_test), epochs=100)
# Out:
# Epoch 1/100
# 1116/1116 [==============================] - 5s 3ms/step - loss: 1072.5282 - val_loss: 76.9282
# Epoch 2/100
# 1116/1116 [==============================] - 4s 3ms/step - loss: 31.2437 - val_loss: 25.7851
# Epoch 3/100
# 1116/1116 [==============================] - 4s 3ms/step - loss: 25.7958 - val_loss: 25.3701
# Epoch 4/100
# 1116/1116 [==============================] - 3s 3ms/step - loss: 25.5109 - val_loss: 25.1438
# Epoch 5/100
# 1116/1116 [==============================] - 2s 2ms/step - loss: 25.3601 - val_loss: 25.0206
# Epoch 6/100
# 1116/1116 [==============================] - 3s 3ms/step - loss: 25.2778 - val_loss: 24.9530
# Epoch 7/100
# 1116/1116 [==============================] - 4s 3ms/step - loss: 25.2252 - val_loss: 24.9119
# Epoch 8/100
# 1116/1116 [==============================] - 3s 3ms/step - loss: 25.1906 - val_loss: 24.8738
# Epoch 9/100
# 1116/1116 [==============================] - 3s 2ms/step - loss: 25.1745 - val_loss: 24.8845
# Epoch 10/100
# ...

# %%
plt.scatter(df_szint.iloc[:,3],df_szint.iloc[:,1])
plt.scatter(df_szint.iloc[:,3],df_szint.iloc[:,2])
plt.show()

# %%
plt.scatter(df_merged.iloc[:,0],df_merged.iloc[:,8])
plt.scatter(df_merged.iloc[:,0],df_merged.iloc[:,9])
plt.scatter(df_merged.iloc[:,0],df_merged.iloc[:,10])
plt.scatter(df_merged.iloc[:,0],df_merged.iloc[:,11])
plt.show()

# %%
df_uj.corr()
import seaborn as sns
sns.heatmap(df_uj.corr())
# Out:
# <Axes: >
